# %% [markdown]
# <a href="https://colab.research.google.com/github/Louris-B/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = str(input("Name: "))
b = int(input("Age: " ))
c = str(input("Course: "))

print("Name: " + a)
print("Age: ", b)
print("Course: " + c)
# Out:
# Name: Lou
# Age: 67
# Course: medicine
# Name: Lou
# Age:  67
# Course: medicine

# %%
a = int(input("Exam Score: "))

if a >= 75:
  print("Passed")
else:
  print("Failed")
# Out:
# Exam Score: 76
# Passed

# %%
a = str(input("Name: "))
b = int(input("Exam Score: "))

if b >= 90:
  print("Letter Grade: A")
elif b >= 80:
  print("Letter Grade: B")
elif b >= 70:
  print("Letter Grade: C")
else:
  print("Letter Grade: F")
# Out:
# Name: lou
# Exam Score: 67
# Letter Grade: F
